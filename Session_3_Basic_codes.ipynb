# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Anumala\\OneDrive\\Documents\\PythonSessions'

# %% [markdown]
# - Whenever we miss the function brackets it will give two indications
#     - 1. function
#     - 2. bound method

# %% [markdown]
# ## CWD
#     - Current working directory

# %%
if =500
# Out:
#   Cell In[4], line 1
#     if =500
#        ^
# SyntaxError: invalid syntax

# %%
name='bangalore'
name
# Out:
# 'bangalore'

# %%
sum=500 # not allowed

# %%
# take three numbers and find the average
n1=200
n2=300
n3=600
avg= (n1+n2+n3)/3
avg
# Out:
# 366.6666666666667

# %%
# write a programme ask the user calculate area of traingle
# pi  = 3.14
# radius = 20
# area = pi*radius*radius

# write a programme ask the user calculate the area of right angle traingle
# area = 0.5*breadth*height

# write a programme ask the user calculate area of rectangle
# area =Length*breadth

# write a programme ask the user take two variables
# bill amount
# Tip amount
#calculate total bill

# write a programme ask the user calculate tax amount
# take 2 variables
# salary
# tax_percentage
# tax= salary*tax_percentage/100

# %%
# write a programme ask the user calculate area of traingle
# pi  = 3.14
# radius = 20
# area = pi*radius*radius

pi = 3.14
radius = 20
area = pi*radius*radius
print(area)
# Out:
# 1256.0

# %%
# write a programme ask the user calculate the area of right angle traingle
# area = 0.5*breadth*height
breadth = 10
height = 20

area = 0.5*breadth*height
print(area)
# Out:
# 100.0

# %%
# write a programme ask the user calculate area of rectangle
# area =Length*breadth
Length = 300
breadth = 200
area = Length*breadth
print(area)
# Out:
# 60000

# %%
# write a programme ask the user take two variables
# bill amount
# Tip amount
#calculate total bill



bill_amount = 3000
tip_amount = 100
total_bill = (bill_amount + tip_amount)
print(total_bill)
# Out:
# 3100

# %%
# write a programme ask the user calculate tax amount
# take 2 variables
# salary
# tax_percentage
# tax= salary*tax_percentage/100

salary = 40000
tax_percentage = 25
tax = salary*tax_percentage/100
print(tax)
# Out:
# 10000.0

# %% [markdown]
# ## Round

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round(9.9876)
# Out:
# 10

# %%
round(9.98765,2)
# Out:
# 9.99

# %%
round(9.98765,3)
