# %% [markdown]
# - Python executes a code, based on some conditions
#
# - those conditions represents with **else-if-elif**
#
# - every condition provides **True or False**
#
# - True means execution accepected
#
# - False means execution not accepected

# %% [markdown]
# ## if

# %%
a=10
a
# Out:
# 10

# %%
a==10
# Out:
# True

# %%
name='python'
name
# Out:
# 'python'

# %%
name='sunil'
name=='sUnil'
# Out:
# False

# %%
'a'>'A' # a = 97 & A = 65
# Out:
# True

# %%
#ascii values

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
chr(97),chr(119)
# Out:
# ('a', 'w')

# %% [markdown]
# ## Syntax

# %%
code 1
if <condition>:
    code here #code 3
    code here #code 4
code 2

# code 1 & code 2 are outside the if 
# code 3 & code 4 are insode the if 

# ==
# !=
# >
# <
# >=
# <=

# %%
a=100
if a==1000:
    print('hello')
else:
    print('bye')
# Out:
# bye

# %% [markdown]
# **indentation**
#
# - adding spce before code
# - when you observe a colon(:), the immdediate lines expected a space
# - if we dont proide the space or not proper space we will get a **indentation error**

# %%
a=100
if a==100:
    print('sunil')
else:
    print('hiii')

    ## Multiple lines comments Ctrl+/
# Out:
# sunil

# %%
if True:  # true/allow
    print('sunil')
# Out:
# sunil

# %%
if False:  # No entry
    print('dfsdfsf')

# %%
print('hi')
if True:
    print('Hello')
print("Bye")
# Out:
# hi
# Hello
# Bye

# %%
print('hi')
if False:
    print('Hello')
    print('sunil')
print("Bye")
# Out:
# hi
# Bye

# %%
print(1)
if True:
    print(2)
    if True:
        print(3)
    print(4)
print(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(1)
if False:
    print(2)
    if True:
        print(3)
    print(4)
print(5)
# Out:
# 1
# 5

# %%
print(1)
if True:
    print(2)
if False:
    print(3)
    print(4)
print(5)
# Out:
# 1
# 2
# 5

# %% [markdown]
# # if and Else

# %% [markdown]
# - when condition is True python excutes the code inside the if block otherwise else block
# - else does not require if any condition to specify

# %%
if <condition>:
    <code>
else: 
    <code>

# %%
if False:
    print('Good condition')
    print('Hello')
else:
    print('Bad condition')
    print('Bye')
# Out:
# Bad condition
# Bye

# %%
if True:
    print('Good condition')
    print('Hello')
print('why are you in middle')  # ivalid syntax error
else:
    print('Bad condition')
    print('Bye')
print('so bye')
# Out:
#   Cell In[63], line 5
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
# wap 
num=eval(input('Enter a number : '))
a=num
if a>=0:
    if a==0:
        print('Print Zero')
    else:
        print('print postive')
else:
    print('print negative')
# Out:
# Enter a number :  -10
# print negative

# %% [markdown]
# ## /  //   %

# %%
25/2    #normal divison
# Out:
# 12.5

# %%
25//2 #floor divison
# Out:
# 12

# %%
25%2  #Modulus operator
# Out:
# 1

# %%
25%2==0
# Out:
# False

# %%
25/2==0
# Out:
# False

# %%
25//2!=0
# Out:
# True

# %%
Number =eval(input('Enter a number:'))
if Number/2==0:
    print(' It is a even number ')
else:
    print('It is a odd number ')
# Out:
# Enter a number: 25
# It is a odd number

# %%
num=eval(input('Enter a number: '))
if num%2==0:
    print(f'{num} is even')
else:
    print(f'{num} is odd')
# Out:
# Enter a number:  25
# 25 is odd

# %%
# ask the user enter howmuch distance you want travel
#assign a variable as user distance
#govt_free_distance=25
#if user distance greater thena gove free distance
#then only ask user enter per km 2rs
#then calculate total charge
#otherwise print enjoy free ride

# %%
import time
user=eval(input('Enter the distance you want to travel : ')) #200
#user_distance=user
govt_free_distance=25
#print(user_distance,govt_free_distance)
if user>govt_free_distance: #200>25
    print('Conductor: You have more distance to travel so pay charge')
    time.sleep(2)
    print('yes sir')
    #distance=user-govt_free_distance #175
    cal_dis = user-govt_free_distance # 175
    print(f'user: okay sir i will pay for {cal_dis}')
    charge=eval(input('Enter the charge per KM'))
    calculate_total_charges=cal_dis*charge
    #distance=eval(input(f'enter per km : {user_distance}'))
    print(calculate_total_charges)
else:
    print('Enjot free ride')
# Out:
# Enter the distance you want to travel :  500
# Conductor: You have more distance to travel so pay charge
# yes sir
# user: okay sir i will pay for 475
# Enter the charge per KM 5
# 2375

# %%
import random
n1=random.randint(1,10)
print(n1)
n2=eval(input('Enter a user number:' ))
if n1==n2:
    print('it is random number')
else:
    print('it is non random number')
# Out:
# 1
# Enter a user number: 40
# it is non random number

# %%
course_name=input('Enter a course name : ')
course=course_name
print(course)
insta_name=input('Enter a institute name : ')
institite=insta_name
if course_name=='ai' and insta_name=='nareshit':
    print('You are safe')
else:
    print('You are not safe')
# Out:
# Enter a course name :  ai
# ai
# Enter a institute name :  nareshit
# You are safe

# %% [markdown]
# # 26-Dec-2025

# %%
# enter the age
# if gender equals to male 
# again ask the user enter the age
# if age greather than 30 then print man
# otherwisse print boy
# else
# again ask the user age
# if age greather than 30 then print woman
# otherwisse print girl

gender = (input('Enter your gender : '))
if gender=='male':
    age=eval(input('Enter the age : '))
    if age>30:
        print('Man')
    else:
        print('Boy')
else:
    age=eval(input('Enter the age : '))
    if age>30:
           print('Woman')
    else:
        print('Girl')
    
# gender = (input('Enter your gender : '))   

# if age>30:
    
#     print('Woman')
# else:
#     print('Girl')
# Out:
# Enter your gender :  femail
# Enter the age :  40
# Woman

# %%
# one condition if else
# two answers
# two condition if elif else
# three answers

if <cond>:
    <code>
    elif:<code>
    <codde>
else:
    <code>

# %%
num=eval(input('Enter a number 1 to 5: '))
if num==1:
    print('one')
elif num==2:
    print('two')
elif num==3:
    print('three')
elif num==4:
    print('four')
else:
    print('five')
# Out:
# Enter a number 1 to 5:  3
# three

# %%
percentage=float(input('Enter the percentage'))
if percentage > 75:
    print('Graade A')
elif percentage <= 75 and percentage >= 60:
    print('Grade B')
elif percentage<=60 and percentage >=45:
    print('Grade C')
elif percentage<=45 and percentage>=35:
    print('Grade D')
else:
    print('Fail')
# Out:
# Enter the percentage 56.8
# Grade C

# %%
percentage=float(input('Enter the percentage'))
if percentage >= 75:
    print('Graade A')
elif percentage >= 60:
    print('Grade B')
elif  percentage >=45:
    print('Grade C')
elif  percentage>=35:
    print('Grade D')
else:
    print('Fail')
# Out:
# Enter the percentage 44.6
# Grade D

# %%
age=eval(input('Enter the age :  '))
if age>=100:
    print('Unlucky person')
elif age>=60:
    print('SS')
elif age>=30:
    print('MA')
elif age>=20:
    print('Young')
elif age>=19:
    print('Teenage')
else:
    print('kid')
# Out:
# Enter the age :   13
# kid
