# %%
a=10
b=20
c=a+b
c

#Shift +enter (Mac : Option+Enter)
# Out:
# 30

# %%
number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 number
#
# NameError: name 'number' is not defined

# %%
a
# Out:
# 10

# %%
sunil =100

# %%
n1=100

# %%
n1
# Out:
# 100

# %%
n3=500

# %%
n3
# Out:
# 500

# %%
print('good morning')
# Out:
# good morning

# %%
import time
time.sleep(5)
print('good morning')

# %%
import time
time.sleep(5)
print('good morning')

# %% [markdown]
# # Pyhton

# %% [markdown]
# ## Python

# %% [markdown]
# ### Python

# %% [markdown]
# #### Python

# %% [markdown]
# ##### Pyhthon

# %% [markdown]
# # Sunil

# %%
b=100
b

# %% [markdown]
# - kernel is white color
#
# - kernel is white color
#
# - kernel is white color

# %% [markdown]
# <img src="https://www.neilsahota.com/wp-content/uploads/2022/09/What-is-AI-how-does-it-work.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1400px; height: 196px; margin: 0px; width: 305px;" alt="What is Artificial Intelligence (AI) and How Does it Work · Neil Sahota" jsname="kn3ccd">

# %% [markdown]
# <img src="https://ideas.darden.virginia.edu/sites/default/files/styles/full_width_1024px_5_3_/public/2024-09/AI%20ART%20ITA.jpg?itok=CIaF2iIX" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1024px; height: 183px; margin: 0px; width: 305px;" alt="AI-Generated Images Raise Age-Old Question: What Is Art? | Darden Ideas to  Action" jsname="kn3ccd">
