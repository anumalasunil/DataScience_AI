# %% [markdown]
# ## Print Statemets

# %% [markdown]
# - print statements are used for only to see outputs
#
# - if we dont print means it's not an error
#
# - we are just not able to see or check the answers

# %%
number =100

# %%
print(number)
# Out:
# 100

# %%
import os

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
n1=100
n2=100

# %%
print(100)
print(100,200)
print(100,200,300)
print(100,200,300,'Apple')
print(n1,n2,300,'Apple')
print('n1','n2',300)
print('n1',n1,'n2',n2,'Apple')
print('n1',n1,'n2',n2,Apple)
# Out:
# 100
# 100 200
# 100 200 300
# 100 200 300 Apple
# 100 100 300 Apple
# n1 n2 300
# n1 100 n2 100 Apple
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       6 print('n1','n2',300)
#       7 print('n1',n1,'n2',n2,'Apple')
# ----> 8 print('n1',n1,'n2',n2,Apple)
#
# NameError: name 'Apple' is not defined

# %%
print('n1 =',n1,'n2 =',n2)
# Out:
# n1 = 100 n2 = 100

# %%
print('n1 =',n1, 'and ' 'n2 =',n2)
# Out:
# n1 = 100 and n2 = 100

# %%
n1=100
n2=200
add=n1+n2
print('The addition of', n1,  'and', n2 , 'is :', add)
#The addition of n1 and n2 is add
#the addition of 100 and 200 is 300
# Out:
# The addition of 100 and 200 is : 300

# %%
#take 3 variables
#name age city
#my name is python im 10 years old and i came from hyderabad

Name='Sunil'
Age = 40
City = 'Bangalore'

print('My name is ', Name, ', I am', Age, 'years old', 'and I came from ', City )
# Out:
# My name is  Sunil , I am 40 years old and I came from  Bangalore

# %% [markdown]
# **format**

# %%
n1=1000
n2=400
add=n1+n2
print('the addition of n1 and n2 is add')
print('The addition of {} and {} is : {}'.format(n1,n2,add))
# Out:
# the addition of n1 and n2 is add
# The addition of 1000 and 400 is : 1400

# %%
#take 3 variables
#name age city
#my name is python im 10 years old and i came from hyderabad

Name='Sunil'
Age = 40
City = 'Bangalore'
print('My name is {} Im {} years old and i came from {}'.format(Name,Age,City))
# Out:
# My name is Sunil Im 40 years old and i came from Bangalore

# %% [markdown]
# **f-string**

# %%
n1=1000
n2=400
add=n1+n2
print('the addition of 1000 and 400 is 1400')
print('the addition of n1 and n2 is add')
#print('The addition of {} and {} is : {}'.format(n1,n2,add))
print(f'The addition of {n1} and {n2} is : {add}')
# Out:
# the addition of 1000 and 400 is 1400
# the addition of n1 and n2 is add
# The addition of 1000 and 400 is : 1400

# %%
#take 3 variables
#name age city
#my name is python im 10 years old and i came from hyderabad

Name='Sunil'
Age = 40
City = 'Bangalore'
#print('My name is {} Im {} years old and i came from {}'.format(Name,Age,City))
print(f'My name is {Name} Im {Age} years old and i came from {City}')
# Out:
# My name is Sunil Im 40 years old and i came from Bangalore

# %%
n1=1000
n2=400
add=n1+n2
print('The addition of 100+200 is 300')
print(f'The addition of {n1}+{n2} is {add}')
print('The addition of {}+{} is {}'.format(n1,n2,add))
# Out:
# The addition of 100+200 is 300
# The addition of 1000+400 is 1400
# The addition of 1000+400 is 1400

# %%
#5X7=35
n1=10
n2=20
f"{n1}X{n2}={n1*n2}"
# Out:
# '10X20=200'

# %% [markdown]
# **End operator**

# %%
# End is:::: Multiple print statements attach together

print(3,end=' ')
print(4,end=' ')
print(10)
# Out:
# 3 4 10

# %% [markdown]
# **Separate**

# %%
print(3,4,5,sep='---->')
# Out:
# 3---->4---->5
