# %%
# this file is opened from folder page
import os
os.getcwd()   #cwd : current working directory
# Out:
# 'C:\\Users\\Anumala\\OneDrive\\Documents\\PythonSessions'

# %% [markdown]
# ## CWD
#  - Current working directory

# %% [markdown]
# ### Data Types

# %% [markdown]
# - integer: int
#
# - float
#
# - bool
#
# - string : str
#
# - list
#
# - tuple
#
# - directionary dict
#
# - complex
#
# - range
#
# - set
#
# - frozenset
#
# - bytes
#
# - bytearray
#
# - memoryview
#
# - None

# %%
n1=100
type(n1)
# Out:
# int

# %% [markdown]
# - If we want to know any type of data or variable we will use

# %% [markdown]
#     - Type inbuilt function

# %% [markdown]
# # Float
#     - float means decimal value representation

# %%
n2 = 100.5
type(n2)
# Out:
# float

# %% [markdown]
# # Exponential data

# %%
1e+1
#<1e> <1>
#1 * <Tell me a number which is having 0:10>
# Out:
# 10.0

# %%
1e+2
# Out:
# 100.0

# %%
1e+5
# Out:
# 100000.0

# %%
5e+2
# Out:
# 500.0

# %%
1e+1  #  1*10
2e+2   #  2*100
3e+3   #  3*1000
4e+4   #  4*10000
5e+5   #  5*100000
# Out:
# 500000.0

# %%
1e1  #  1*10
2e2   #  2*100
3e3   #  3*1000
4e4   #  4*10000
5e5   #  5*100000
# Out:
# 500000.0

# %%
1e+1  , 1e1
# Out:
# (10.0, 10.0)

# %%
1e-1
# Out:
# 0.1

# %%
2e+2, 2e-2
# Out:
# (200.0, 0.02)

# %%
3e+3, 3e-3
# Out:
# (3000.0, 0.003)

# %%
4e+4, 4e-4
# Out:
# (40000.0, 0.0004)

# %%
1e+1, 1e-1
1e-2, 1e/1
# Out:
#   Cell In[15], line 2
#     1e-2, 1e/1
#           ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ****Strings****

# %%
city='Hyderabad'  #single quotes
type(city)
# Out:
# str

# %%
name="Naresh IT"  #double quotes
type(name)
# Out:
# str

# %%
location = "Bangalore'
location
# Out:
#   Cell In[20], line 1
#     location = "Bangalore'
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1 ='hello'
len(s1)
# Out:
# 5

# %%
s2='word      '
len(s2)
# Out:
# 10

# %%
s1,s2
# Out:
# ('hello', 'word      ')

# %%
print(s1,s2)
# Out:
# hello word

# %%
s4=''
len(s4)
# Out:
# 0

# %%
s5=' '
len(s5)
# Out:
# 1

# %%
print('I like "Pyhthon"')
# Out:
# I like "Pyhthon"

# %%
print("I like 'Python'")
# Out:
# I like 'Python'

# %% [markdown]
# - Strings can be **single quotes**
#
# - Strings can be **double quotes**
#
# - Python by default use **single quotes** only
#
# - when print the stringe we need to be carefull
#
# - If we want to highlight any word, then keep entire string in **Single quotes**
#
#         - and highlighted word in $$double$$ $Single$ vice versa

# %% [markdown]
# ## Doc String

# %%
"Hello how are you
I'm Fine"  =====>Fail

'Hello how are you
I'm Fine'  ======> Fail

# %%
s1="""Hello how are you
I'm Fine"""
s1
# Out:
# "Hello how are you\nI'm Fine"

# %% [markdown]
# - But triple quotes are not recomeneded
#
# - triple quotes are used to communicate the information
#
# - If any user writing triple quotes
#
# - this is called as **Doc string**

# %%
import os
os.getcwd()  #Shift+Tab
# Out:
# 'C:\\Users\\Anumala\\OneDrive\\Documents\\PythonSessions'

# %% [markdown]
# **boolean Data Type**
#
# - True means 1 : ON
#
# - False means 0 : OFF
#
#     - Something is not available means is off

# %%
val1 = True
type(val1)
# Out:
# bool

# %%
val2= False
type(val2)
# Out:
# bool

# %%
v1= True    #Boolean
str="True"  #String
true=10  #Variable
type(v1),type(str),type(true)
# Out:
# (bool, str, int)

# %% [markdown]
# - int
#
# - bool
#
# - str
#
# - bool
